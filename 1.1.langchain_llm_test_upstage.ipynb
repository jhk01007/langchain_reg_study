# %% [markdown]
# 1. 필요한 패키지 설치

# %%
# %pip install langchain-openai python-dotenv
# Out:
# Collecting langchain-openai
#   Obtaining dependency information for langchain-openai from https://files.pythonhosted.org/packages/78/9b/7af1d539a051d195c5ecc5990ebd483f208c40f75a8a9532846d16762704/langchain_openai-1.0.2-py3-none-any.whl.metadata
#   Using cached langchain_openai-1.0.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting python-dotenv
#   Obtaining dependency information for python-dotenv from https://files.pythonhosted.org/packages/14/1b/a298b06749107c305e1fe0f814c6c74aea7b2f1e10989cb30f544a1b3253/python_dotenv-1.2.1-py3-none-any.whl.metadata
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting langchain-core<2.0.0,>=1.0.2 (from langchain-openai)
#   Obtaining dependency information for langchain-core<2.0.0,>=1.0.2 from https://files.pythonhosted.org/packages/f2/1b/b0a37674bdcbd2931944e12ea742fd167098de5212ee2391e91dce631162/langchain_core-1.0.3-py3-none-any.whl.metadata
#   Using cached langchain_core-1.0.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting openai<3.0.0,>=1.109.1 (from langchain-openai)
#   Obtaining dependency information for openai<3.0.0,>=1.109.1 from https://files.pythonhosted.org/packages/8c/74/6bfc3adc81f6c2cea4439f2a734c40e3a420703bbcdc539890096a732bbd/openai-2.7.1-py3-none-any.whl.metadata
#   Using cached openai-2.7.1-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Obtaining dependency information for tiktoken<1.0.0,>=0.7.0 from https://files.pythonhosted.org/packages/4a/42/6573e9129bc55c9bf7300b3a35bef2c6b9117018acca0dc760ac2d93dffe/tiktoken-0.12.0-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Using cached tiktoken-0.12.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.0.2->langchain-openai)
#   Obtaining dependency information for jsonpatch<2.0.0,>=1.33.0 from https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl.metadata
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.0.2->langchain-openai)
#   Obtaining dependency information for langsmith<1.0.0,>=0.3.45 from https://files.pythonhosted.org/packages/98/4c/6c0c338ca7182e4ecb7af61049415e7b3513cc6cea9aa5bf8ca508f53539/langsmith-0.4.41-py3-none-any.whl.metadata
#   Using cached langsmith-0.4.41-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in ./.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (25.0)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain-core<2.0.0,>=1.0.2->langchain-openai)
#   Obtaining dependency information for pydantic<3.0.0,>=2.7.4 from https://files.pythonhosted.org/packages/82/2f/e68750da9b04856e2a7ec56fc6f034a5a79775e9b9a81882252789873798/pydantic-2.12.4-py3-none-any.whl.metadata
#   Using cached pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.0.2->langchain-openai)
#   Obtaining dependency information for tenacity!=8.4.0,<10.0.0,>=8.1.0 from https://files.pythonhosted.org/packages/e5/30/643397144bfbfec6f6ef821f36f33e57d35946c44a2352d3c9f0ae847619/tenacity-9.1.2-py3-none-any.whl.metadata
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.2->langchain-openai) (4.15.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.12/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.11.0)
# Collecting distro<2,>=1.7.0 (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Obtaining dependency information for distro<2,>=1.7.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.12/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Obtaining dependency information for jiter<1,>=0.10.0 from https://files.pythonhosted.org/packages/f7/29/6c7de6b5d6e511d9e736312c0c9bfcee8f9b6bef68182a08b1d78767e627/jiter-0.11.1-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Using cached jiter-0.11.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.12/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Collecting tqdm>4 (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Obtaining dependency information for tqdm>4 from https://files.pythonhosted.org/packages/d0/30/dc54f88dd4a2b5dc8a0279bdd7270e735851848b762aeb1c1184ed1f6b14/tqdm-4.67.1-py3-none-any.whl.metadata
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Obtaining dependency information for regex>=2022.1.18 from https://files.pythonhosted.org/packages/bf/26/0a575f58eb23b7ebd67a45fccbc02ac030b737b896b7e7a909ffe43ffd6a/regex-2025.11.3-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Using cached regex-2025.11.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: requests>=2.26.0 in ./.venv/lib/python3.12/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.32.5)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain-openai) (3.11)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain-openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.2->langchain-openai) (3.0.0)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai)
#   Obtaining dependency information for orjson>=3.9.14 from https://files.pythonhosted.org/packages/1c/2c/2602392ddf2601d538ff11848b98621cd465d1a1ceb9db9e8043181f2f7b/orjson-3.11.4-cp312-cp312-macosx_15_0_arm64.whl.metadata
#   Using cached orjson-3.11.4-cp312-cp312-macosx_15_0_arm64.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai)
#   Obtaining dependency information for requests-toolbelt>=1.0.0 from https://files.pythonhosted.org/packages/3f/51/d4db610ef29373b879047326cbf6fa98b6c1969d6f6dc423279de2b1be2c/requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain-openai)
#   Obtaining dependency information for zstandard>=0.23.0 from https://files.pythonhosted.org/packages/aa/1c/d920d64b22f8dd028a8b90e2d756e431a5d86194caa78e3819c7bf53b4b3/zstandard-0.25.0-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Using cached zstandard-0.25.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain-openai)
#   Obtaining dependency information for annotated-types>=0.6.0 from https://files.pythonhosted.org/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl.metadata
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain-openai)
#   Obtaining dependency information for pydantic-core==2.41.5 from https://files.pythonhosted.org/packages/aa/32/9c2e8ccb57c01111e0fd091f236c7b371c1bccea0fa85247ac55b1e2b6b6/pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Using cached pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain-openai)
#   Obtaining dependency information for typing-inspection>=0.4.2 from https://files.pythonhosted.org/packages/dc/9b/47798a6c91d8bdb567fe2698fe81e0c6b7cb7ef4d13da4114b41d239f65d/typing_inspection-0.4.2-py3-none-any.whl.metadata
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.5.0)
# Using cached langchain_openai-1.0.2-py3-none-any.whl (81 kB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached langchain_core-1.0.3-py3-none-any.whl (469 kB)
# Using cached openai-2.7.1-py3-none-any.whl (1.0 MB)
# Using cached tiktoken-0.12.0-cp312-cp312-macosx_11_0_arm64.whl (994 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.11.1-cp312-cp312-macosx_11_0_arm64.whl (315 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langsmith-0.4.41-py3-none-any.whl (399 kB)
# Using cached pydantic-2.12.4-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl (1.9 MB)
# Using cached regex-2025.11.3-cp312-cp312-macosx_11_0_arm64.whl (288 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached orjson-3.11.4-cp312-cp312-macosx_15_0_arm64.whl (128 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached zstandard-0.25.0-cp312-cp312-macosx_11_0_arm64.whl (640 kB)
# Installing collected packages: zstandard, typing-inspection, tqdm, tenacity, regex, python-dotenv, pydantic-core, orjson, jsonpatch, jiter, distro, annotated-types, tiktoken, requests-toolbelt, pydantic, openai, langsmith, langchain-core, langchain-openai
# Successfully installed annotated-types-0.7.0 distro-1.9.0 jiter-0.11.1 jsonpatch-1.33 langchain-core-1.0.3 langchain-openai-1.0.2 langsmith-0.4.41 openai-2.7.1 orjson-3.11.4 pydantic-2.12.4 pydantic-core-2.41.5 python-dotenv-1.2.1 regex-2025.11.3 requests-toolbelt-1.0.0 tenacity-9.1.2 tiktoken-0.12.0 tqdm-4.67.1 typing-inspection-0.4.2 zstandard-0.25.0
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 2. 환경변수 불러오기

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# 3. LangChain 써보기 (Upstage)

# %%
from langchain_upstage import ChatUpstage

llm = ChatUpstage()

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")
ai_message
# Out:
# AIMessage(content='인프런에는 다양한 분야의 강의가 있습니다. 주요 카테고리는 다음과 같습니다:\n\n1. **프로그래밍**: 웹 개발, 모바일 개발, 게임 개발, 데이터 과학, 머신러닝, 인공지능, 네트워크 프로그래밍 등 다양한 프로그래밍 언어로 구성된 강의가 있습니다.\n\n2. **디자인**: UI/UX 디자인, 그래픽 디자인, 웹 디자인, UX/UI 연구, 브랜드 디자인 등 디자인 관련 강의가 있습니다.\n\n3. **비즈니스**: 마케팅, 경영, 재무, 회계, 창업, 리더십 등 비즈니스 관련 강의가 있습니다.\n\n4. **인문학**: 심리학, 철학, 역사, 사회학 등 인문학 관련 강의가 있습니다.\n\n5. **생활**: 요리, 건강, 여행, 취미 등 생활 관련 강의가 있습니다.\n\n6. **기타**: 사진, 음악, 미술, 외국어 등 다양한 분야의 강의가 있습니다.\n\n인프런에서는 실무에 바로 적용 가능한 실용적인 강의를 제공하는 것이 특징으로, 많은 강의들이 실습 중심으로 구성되어 있습니다. 또한, 각 분야의 전문가들이 직접 강의를 진행하기 때문에 높은 품질의 교육을 받을 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 233, 'prompt_tokens': 19, 'total_tokens': 252, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'solar-mini-250422', 'system_fingerprint': None, 'id': 'e72554f9-040d-47b0-aa4c-c6d52079901a', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--e57bee53-6d68-4845-8768-800d6d580c8e-0', usage_metadata={'input_tokens': 19, 'output_tokens': 233, 'total_tokens': 252, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
ai_message.content
# Out:
# '인프런에는 다양한 분야의 강의가 있습니다. 주요 카테고리는 다음과 같습니다:\n\n1. **프로그래밍**: 웹 개발, 모바일 개발, 게임 개발, 데이터 과학, 머신러닝, 인공지능, 네트워크 프로그래밍 등 다양한 프로그래밍 언어로 구성된 강의가 있습니다.\n\n2. **디자인**: UI/UX 디자인, 그래픽 디자인, 웹 디자인, UX/UI 연구, 브랜드 디자인 등 디자인 관련 강의가 있습니다.\n\n3. **비즈니스**: 마케팅, 경영, 재무, 회계, 창업, 리더십 등 비즈니스 관련 강의가 있습니다.\n\n4. **인문학**: 심리학, 철학, 역사, 사회학 등 인문학 관련 강의가 있습니다.\n\n5. **생활**: 요리, 건강, 여행, 취미 등 생활 관련 강의가 있습니다.\n\n6. **기타**: 사진, 음악, 미술, 외국어 등 다양한 분야의 강의가 있습니다.\n\n인프런에서는 실무에 바로 적용 가능한 실용적인 강의를 제공하는 것이 특징으로, 많은 강의들이 실습 중심으로 구성되어 있습니다. 또한, 각 분야의 전문가들이 직접 강의를 진행하기 때문에 높은 품질의 교육을 받을 수 있습니다.'
