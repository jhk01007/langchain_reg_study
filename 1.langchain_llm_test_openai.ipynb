# %% [markdown]
# 1. 필요한 패키지 설치

# %%
# %pip install -q langchain-upstage python-dotenv
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 2. 환경변수 불러오기

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# 3. LangChain 써보기(OpenAI)

# %%
from langchain_openai import ChatOpenAI
import os

api_key = os.getenv("OPENAI_API_KEY") # api key를 OPENAI_API_KEY로 환경변수에 저장하면 이 부분을 생략할 수 있다.

llm = ChatOpenAI(api_key=api_key) # 변수명은 llm으로 쓰는 것이 관례

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")
ai_message
# Out:
# AIMessage(content='인프런에는 다양한 분야의 강의가 있습니다. 프로그래밍, 웹 개발, 데이터 분석, 마케팅, 디자인, 투자 등 다양한 주제의 강의를 제공하고 있습니다. 또한 인프런은 전문가들이 직접 강의를 제작하고 업데이트하므로 최신 트렌드와 정보를 학습할 수 있는 매력적인 플랫폼입니다. 원하는 주제나 분야의 강의를 검색하여 수강할 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 168, 'prompt_tokens': 26, 'total_tokens': 194, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CYtK44rDMRldXCDPh53l6CPGcWkxN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--46f7588c-6cf1-4bfa-828b-eb95469512ff-0', usage_metadata={'input_tokens': 26, 'output_tokens': 168, 'total_tokens': 194, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 
# ...

# %%
ai_message.content
# Out:
# '인프런(Inflearn)은 국내 최대 규모의 온라인 교육 플랫폼으로서, 다양한 분야와 주제의 강의를 제공하고 있습니다. 일반적으로는 프로그래밍, 웹 개발, 데이터 분석 등의 IT 관련 강의부터 마케팅, 디자인, 비즈니스 등의 강의까지 다양한 주제를 다루고 있습니다. 또한, 강의내용에 따라 초급, 중급, 고급 등 강의 난이도도 다양하게 제공되어 있습니다.\n\n특히, 최근에는 인공지능, 머신러닝, 딥러닝 등 인공지능 관련 강의가 늘어나고 있으며, 해외진출을 준비하는 분들을 위한 영어 강의도 제공되고 있습니다.\n\n관심 있는 분야나 주제에 맞춰 인프런에서 제공하는 강의를 검색하여 공부하시면 도움이 될 것입니다.'
