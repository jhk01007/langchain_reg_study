# %% [markdown]
# 1. 필요한 패키지 설치

# %%
# %pip install -q langchain-openai python-dotenv
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 2. 환경변수 불러오기

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# 3. LangChain 써보기(OpenAI)

# %%
from langchain_openai import ChatOpenAI
import os

api_key = os.getenv("OPENAI_API_KEY") # api key를 OPENAI_API_KEY로 환경변수에 저장하면 이 부분을 생략할 수 있다.

llm = ChatOpenAI(api_key=api_key) # 변수명은 llm으로 쓰는 것이 관례

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")
ai_message
# Out:
# AIMessage(content='인프런에는 다양한 분야의 강의들이 있습니다. 프로그래밍, 디자인, 비즈니스, 투자, 언어 등 다양한 주제의 강의들이 제공되고 있습니다. 개인의 관심사나 필요에 맞게 다양한 강의를 찾아 수강할 수 있습니다. 또한 전문가들의 온라인 강의를 통해 실무 능력을 향상시킬 수 있습니다. 관심 있는 주제의 강의를 찾아보시면 좋을 것입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 164, 'prompt_tokens': 26, 'total_tokens': 190, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CYuEjJO5mu0LOCpsDt0gz4inadGFN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--6a13563c-8c57-41ba-906f-1890ea203682-0', usage_metadata={'input_tokens': 26, 'output_tokens': 164, 'total_tokens': 190, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
ai_message.content
# Out:
# '인프런에는 다양한 분야의 강의들이 있습니다. 프로그래밍, 디자인, 비즈니스, 투자, 언어 등 다양한 주제의 강의들이 제공되고 있습니다. 개인의 관심사나 필요에 맞게 다양한 강의를 찾아 수강할 수 있습니다. 또한 전문가들의 온라인 강의를 통해 실무 능력을 향상시킬 수 있습니다. 관심 있는 주제의 강의를 찾아보시면 좋을 것입니다.'
